# %% [markdown]
# <a href="https://colab.research.google.com/github/S1wol0423/data-medical/blob/main/01_collecting_bigdata_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # HTTP Request를 활용한 데이터 수집

# %%
import requests, sys

# 요청 url 설정
server_url = "https://rest.ensembl.org"
ext_url = "/overlap/id/ENSG00000157764?feature=gene"

# HTTP GET method 호출
r = requests.get(server_url + ext_url, headers={ "Content-Type" : "application/json"})

# 예외 처리
if not r.ok:
  r.raise_for_status()
  sys.exit()

# Response 확인
decoded = r.json()
print(repr(decoded))
# Out:
# [{'seq_region_name': '7', 'canonical_transcript': 'ENST00000247866.9', 'feature_type': 'gene', 'id': 'ENSG00000090266', 'assembly_name': 'GRCh38', 'logic_name': 'ensembl_havana_gene_homo_sapiens', 'biotype': 'protein_coding', 'end': 140722790, 'start': 140690777, 'source': 'ensembl_havana', 'external_name': 'NDUFB2', 'description': 'NADH:ubiquinone oxidoreductase subunit B2 [Source:HGNC Symbol;Acc:HGNC:7697]', 'gene_id': 'ENSG00000090266', 'version': 13, 'strand': 1}, {'id': 'ENSG00000271932', 'seq_region_name': '7', 'canonical_transcript': 'ENST00000605989.1', 'feature_type': 'gene', 'biotype': 'snRNA', 'end': 140884178, 'start': 140884072, 'source': 'ensembl', 'assembly_name': 'GRCh38', 'logic_name': 'ncrna_homo_sapiens', 'description': 'RNA, U6 small nuclear 85, pseudogene [Source:HGNC Symbol;Acc:HGNC:47048]', 'external_name': 'RNU6-85P', 'gene_id': 'ENSG00000271932', 'strand': 1, 'version': 1}, {'logic_name': 'havana_homo_sapiens', 'assembly_name': 'GRCh38', 'source': 'havana', '
# ...

# %%
# 데이터 프레임 형태로 저장 및 출력
import pandas as pd
df = pd.DataFrame(decoded)
df
# Out:
#   seq_region_name canonical_transcript feature_type               id  \
# 0               7    ENST00000247866.9         gene  ENSG00000090266
# 1               7    ENST00000605989.1         gene  ENSG00000271932
# 2               7    ENST00000700122.1         gene  ENSG00000289788
# 3               7    ENST00000646891.2         gene  ENSG00000157764
#
#   assembly_name                        logic_name         biotype        end  \
# 0        GRCh38  ensembl_havana_gene_homo_sapiens  protein_coding  140722790
# 1        GRCh38                ncrna_homo_sapiens           snRNA  140884178
# 2        GRCh38               havana_homo_sapiens          lncRNA  140795643
# 3        GRCh38  ensembl_havana_gene_homo_sapiens  protein_coding  140924929
#
#        start          source external_name  \
# 0  140690777  ensembl_havana        NDUFB2
# 1  140884072         ensembl      RNU6-85P
# 2  140767530          havana           NaN
# 3  140719327  ensembl_havana          BRAF
#
# ...

# %% [markdown]
# # BeautifulSoup를 활용한 크롤링

# %%
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# %%
# target url
url = "https://www.naver.com"

# 웹페이지 호출
response = requests.get(url, timeout=5)
soup = BeautifulSoup(response.content, "html.parser")

# 확인
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="fzoom" lang="ko">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="origin" name="Referrer"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=1190" name="viewport"/>
#   <title>
#    NAVER
#   </title>
#   <meta content="NAVER" name="apple-mobile-web-app-title">
#    <meta content="index,nofollow" name="robots">
#     <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" name="description">
#      <meta content="네이버" property="og:title"/>
#      <meta content="https://www.naver.com/" property="og:url"/>
#      <meta content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png" property="og:image"/>
#      <meta content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요" property="og:description">
#       <meta content="summary" name="twitter:card"/>
#       <meta content="" name="twitter:title"/>
#       <meta content="https://www.naver.com/" name="twitter:url"/>
# ...
